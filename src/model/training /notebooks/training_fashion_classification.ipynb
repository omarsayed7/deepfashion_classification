# %% [markdown]
# <a href="https://colab.research.google.com/github/omarsayed7/deepfashion_classification/blob/main/src/model/training%20/notebooks/training_fashion_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf deepfashion_classification/

# %% [markdown]
# # Clone the project github repo

# %%
# !git clone https://github.com/omarsayed7/deepfashion_classification.git
# Out:
# Cloning into 'deepfashion_classification'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 155 (delta 56), reused 142 (delta 43), pack-reused 0
# Receiving objects: 100% (155/155), 943.84 KiB | 20.97 MiB/s, done.
# Resolving deltas: 100% (56/56), done.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Install dependencies

# %%
# !pip install -r  deepfashion_classification/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 50.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 25.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 102.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 117.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 125.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 37.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 48.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 kB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 118.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Setup some directories and create logging csv file

# %%
# !cd deepfashion_classification/src/model/training && python main.py -script_mode setup
# Out:
# [INFO] Starting to Setup the project

# %% [markdown]
# # Copy the data from google drive to /data directory

# %%
# !cp /content/drive/MyDrive/DeepFashion/Category\ and\ Attribute\ Prediction\ Benchmark/Img/img.zip  ./deepfashion_classification/data/

# %%
# !unzip deepfashion_classification/data/img.zip -d ./deepfashion_classification/data/classification_data/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./deepfashion_classification/data/classification_data/img/Woven_Dolphin_Shorts/img_00000028.jpg
#   inflating: ./deepfashion_classification/data/classification_data/img/Woven_Dolphin_Shorts/img_00000029.jpg
#   inflating: ./deepfashion_classification/data/classification_data/img/Woven_Dolphin_Shorts/img_00000030.jpg
#   inflating: ./deepfashion_classification/data/classification_data/img/Woven_Dolphin_Shorts/img_00000031.jpg
#   inflating: ./deepfashion_classification/data/classification_data/img/Woven_Dolphin_Shorts/img_00000032.jpg
#   inflating: ./deepfashion_classification/data/classification_data/img/Woven_Dolphin_Shorts/img_00000033.jpg
#   inflating: ./deepfashion_classification/data/classification_data/img/Woven_Dolphin_Shorts/img_00000034.jpg
#   inflating: ./deepfashion_classification/data/classification_data/img/Woven_Dolphin_Shorts/img_00000035.jpg
# ...

# %%
# !cp /content/drive/MyDrive/DeepFashion/Category\ and\ Attribute\ Prediction\ Benchmark/Anno_coarse/list_category_img.txt  ./deepfashion_classification/data/classification_data/raw_annotations

# %% [markdown]
# Build Dataset

# %%
# !cd deepfashion_classification/src/data && python build_dataset.py -sampling_threshold 1000 -maximum_num_images 1000
# Out:
# [INFO] Starting to build fashion data
# [INFO] Number of sampled classes 22
# {0: 'Leggings', 1: 'Tank', 2: 'Joggers', 3: 'Blazer', 4: 'Romper', 5: 'Shorts', 6: 'Cardigan', 7: 'Sweatpants', 8: 'Tee', 9: 'Hoodie', 10: 'Sweatshorts', 11: 'Skirt', 12: 'Coat', 13: 'Cutoffs', 14: 'Kimono', 15: 'Top', 16: 'Dress', 17: 'Sweater', 18: 'Blouse', 19: 'Jeans', 20: 'Jumpsuit', 21: 'Jacket'}
# [INFO] Distribution of the sampled classes Counter({'Blouse': 1000, 'Blazer': 1000, 'Tee': 1000, 'Tank': 1000, 'Top': 1000, 'Sweater': 1000, 'Hoodie': 1000, 'Cardigan': 1000, 'Jacket': 1000, 'Skirt': 1000, 'Shorts': 1000, 'Jeans': 1000, 'Joggers': 1000, 'Sweatpants': 1000, 'Cutoffs': 1000, 'Sweatshorts': 1000, 'Leggings': 1000, 'Dress': 1000, 'Romper': 1000, 'Coat': 1000, 'Kimono': 1000, 'Jumpsuit': 1000})
# [INFO] Total number of images 22000
# [INFO] Finished parsing the fashion dataset and saved to {dataframe_path}/fashion_data.csv

# %% [markdown]
# # Train the model

# %%
# !cd deepfashion_classification/src/model/training && python main.py -script_mode train -epochs 20 -model_name efficientnet-b0 -use_wandb True -experiment_version 3
# Out:
# [INFO] Starting to training the 3 experiment
# Train data: 16460, Validation data: 2680, Test data: 2680
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /content/deepfashion_classification/src/model/training/wandb/run-20230521_170633-rysl26xe
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run honest-pyramid-6
# wandb: ⭐️ View project at https://wandb.ai/sayedomar74/fashion-classification
# ...

# %%
# !cp -r /content/deepfashion_classification/models/efficientnet-b0_0.0001_True_64_categorical_crossentropy_0.5_False_20_V3 /content/drive/MyDrive

# %%
# !cd deepfashion_classification/src/model/training && python main.py -script_mode train -epochs 20 -model_name efficientnet-b7 -use_wandb True -freeze_backbone True -experiment_version 4
# Out:
# [INFO] Starting to training the 4 experiment
# Train data: 16460, Validation data: 2680, Test data: 2680
# wandb: Currently logged in as: sayedomar74. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /content/deepfashion_classification/src/model/training/wandb/run-20230521_181522-klnjkgjp
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run stellar-vortex-7
# wandb: ⭐️ View project at https://wandb.ai/sayedomar74/fashion-classification
# wandb: 🚀 View run at https://wandb.ai/sayedomar74/fashion-classification/runs/klnjkgjp
# Downloading: "https://download.pytorch.org/models/efficientnet_b7_lukemelas-dcc49843.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b7_lukemelas-dcc49843.pth
# 100% 255M/255M [00:02<00:00, 89.9MB/s]
# 64,448,230 total parameters.
# 661,270 training parameters.
#
# ...

# %%
# !cp -r /content/deepfashion_classification/models/efficientnet-b7_0.0001_True_64_categorical_crossentropy_0.5_True_20_V4 /content/drive/MyDrive

# %%
# !cd deepfashion_classification/src/model/training && python main.py -script_mode train -epochs 20 -model_name resnet-50 -use_wandb True -experiment_version 2
# Out:
# [INFO] Starting to training the 1 experiment
# Train data: 16460, Validation data: 2680, Test data: 2680
# wandb: Currently logged in as: sayedomar74. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.3
# wandb: Run data is saved locally in /content/deepfashion_classification/src/model/training/wandb/run-20230520_201220-643mk5mk
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run jumping-gorge-31
# wandb: ⭐️ View project at https://wandb.ai/sayedomar74/fashion-classification
# wandb: 🚀 View run at https://wandb.ai/sayedomar74/fashion-classification/runs/643mk5mk
# 24,038,230 total parameters.
# 24,038,230 training parameters.
#
# Start training experiment  1  :  resnet-50 0.001 True 128 categorical crossentropy 0.3 False 100 V1
# [INFO]: Epoch 1 of 100 -- V1
# Training
# 100% 129/129 [02:56<00:00,  1.37s/it]
# Validation
# 100% 21/21 [00:18<00:00,  1.12it/s]
# ...
